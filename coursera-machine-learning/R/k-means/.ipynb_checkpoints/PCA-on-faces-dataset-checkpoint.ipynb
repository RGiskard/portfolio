# %%
#En este ejemplo utilizaremos el algoritmo PCA en imágenes de rostros para ver como puede utilizarse en la práctica para
#reducción de dimensionalidad.

#Este dataset contiene 5000 imágenes de rostros de 32 x 32 en escala de grises. Cada fila corresponde a una imagen, por lo
#tanto la matriz tiene 5000 filas y 1024 (32x32) columnas.

# %%
#Configuración de tamaño de gráficos
options(repr.plot.width=5, repr.plot.height=4, scipen = 999)

# %%
#Instalación y carga de paquetes necesarios
list.of.packages <- c('ggplot2', 'R.matlab', 'ggthemes')

new.packages <- list.of.packages[!(list.of.packages %in% installed.packages()[,"Package"])]
if(length(new.packages)) install.packages(new.packages, repos = "https://cran.r-project.org")

library(ggplot2)
library(R.matlab)
library(ggthemes)
# Out:
# R.matlab v3.6.1 (2016-10-19) successfully loaded. See ?R.matlab for help.
#
# Attaching package: 'R.matlab'
#
# The following objects are masked from 'package:base':
#
#     getOption, isOpen

# %%
#Carga de datos
X <- as.data.frame(readMat('ex7faces.mat'))
str(X)
# Out:
# 'data.frame':	5000 obs. of  1024 variables:
#  $ X.1   : num  -37.87 8.13 -32.87 -84.87 2.13 ...
#  $ X.2   : num  -45.866 -0.866 -34.866 -64.866 6.134 ...
#  $ X.3   : num  -53.87 -8.87 -36.87 -47.87 5.13 ...
#  $ X.4   : num  -51.87 -15.87 -18.87 -42.87 9.13 ...
#  $ X.5   : num  -40.87 -17.87 6.13 -38.87 10.13 ...
#  $ X.6   : num  -33.9 -16.9 15.1 -28.9 11.1 ...
#  $ X.7   : num  -47.87 -15.87 -1.87 -17.87 11.13 ...
#  $ X.8   : num  -37.9 -21.9 -31.9 -11.9 11.1 ...
#  $ X.9   : num  -22.87 -42.87 -1.87 -10.87 12.13 ...
#  $ X.10  : num  -7.87 -28.87 13.13 -12.87 12.13 ...
#  $ X.11  : num  -5.87 -19.87 12.13 -33.87 11.13 ...
#  $ X.12  : num  -15.87 -19.87 6.13 -44.87 10.13 ...
#  $ X.13  : num  -22.87 -18.87 3.13 -26.87 8.13 ...
#  $ X.14  : num  -27.87 -15.87 7.13 -27.87 7.13 ...
#  $ X.15  : num  -18.87 -17.87 6.13 -29.87 6.13 ...
#  $ X.16  : num  -20.87 -21.87 3.13 -29.87 5.13 ...
#  $ X.17  : num  -33.87 -26.87 4.13 -28.87 5.13 ...
#  $ X.18  : num  -71.87 -31.87 4.13 -23.87 5.13 ...
#  $ X.19  : num  -113.87 -29.87 6.13 -19.87 6.13 ...
#  $ X.20  : num  -116.87 -15.87 3.13 -22.87 5.13 ...
#  $ X.21  : num  -115.866 -12.866 0.134 -20.866 5.134 ...
#  $ X.22  : num  -116.87 -28.87 -3.87 -22.87 6.13 ...
#  $ X.23  : num  -117.87 -30.87 -9.87 -24.87 8.13 ...
#  $ X.24  : num  -114.9 -29.9 -23.9 -23.9 -29.9 ...
#  $ X.25  : num  -85.9 -33.9 -32.9 -27.9 -94.9 ...
#  $ X.26  : num  -59.9 -35.9 -36.9 -36.9 -102.9 ...
#  $ X.27  : num  -56.9 -35.9 -35.9 -22.9 -103.9 ...
#  $ X.28  : num  -59.87 -34.87 -29.87 2.13 -106.87 ...
#  $ X.29  : num  -66.9 -34.9 -32.9 16.1 -109.9 ...
#  $ X.71  : num  -68.87 1.13 35.13 -7.87 -2.87 ...
#  $ X.72  : num  -49.866 -0.866 35.134 -14.866 -2.866 ...
#  $ X.73  : num  -29.87 -23.87 -10.87 -25.87 -1.87 ...
#  $ X.74  : num  -28.87 -35.87 -3.87 -42.87 -3.87 ...
#  $ X.75  : num  -35.87 -9.87 23.13 -43.87 -2.87 ...
#  $ X.76  : num  -38.87 2.13 21.13 -21.87 -10.87 ...
#  $ X.77  : num  -40.866 0.134 25.134 -19.866 -10.866 ...
#  $ X.78  : num  -33.87 -2.87 26.13 -10.87 -11.87 ...
#  $ X.79  : num  -22.87 -5.87 15.13 -11.87 -11.87 ...
#  $ X.80  : num  -25.87 -3.87 15.13 -11.87 -9.87 ...
#  $ X.81  : num  -27.87 -3.87 18.13 -20.87 -7.87 ...
#  $ X.82  : num  -27.87 -11.87 16.13 -29.87 -4.87 ...
#  $ X.83  : num  -31.87 -21.87 13.13 -31.87 -1.87 ...
#  $ X.84  : num  -36.866 -30.866 6.134 -31.866 -0.866 ...
#  $ X.85  : num  -38.87 -38.87 2.13 -30.87 2.13 ...
#  $ X.86  : num  -44.866 -42.866 -0.866 -31.866 2.134 ...
#  $ X.87  : num  -48.87 -45.87 -1.87 -32.87 -6.87 ...
#  $ X.88  : num  -58.87 -51.87 1.13 -31.87 -66.87 ...
#  $ X.89  : num  -84.87 -48.87 -3.87 -33.87 -87.87 ...
#  $ X.90  : num  -96.9 -42.9 -11.9 -35.9 -76.9 ...
#  $ X.91  : num  -108.9 -38.9 -17.9 -39.9 -76.9 ...
#  $ X.92  : num  -110.9 -40.9 -19.9 -42.9 -74.9 ...
#  $ X.93  : num  -111.9 -45.9 -21.9 -46.9 -79.9 ...
#  $ X.94  : num  -111.9 -51.9 -25.9 -47.9 -86.9 ...
#  $ X.95  : num  -111.9 -50.9 -25.9 -47.9 -91.9 ...
#  $ X.96  : num  -112.9 -41.9 -15.9 -38.9 -98.9 ...
#  $ X.97  : num  -13.87 19.13 30.13 1.13 12.13 ...
#  $ X.98  : num  -3.87 20.13 33.13 2.13 6.13 ...
#  $ X.99  : num  -16.87 19.13 37.13 2.13 -15.87 ...
#   [list output truncated]

# %%
#Visualizamos una muestra del dataset

m <- nrow(X)
rand_indices <- sample(m, 100)
sel <- X[rand_indices, ]

displayData <- function(X) {
    
    
    example_width <- round(sqrt(dim(X)[2]))
    
    if (is.vector(X))
        X <- t(X)
  
    # Calcular número de filas y columnas
    m <- dim(X)[1]
    n <- dim(X)[2]

    example_height <- (n / example_width) #altura en pixeles de c/imagen

    # Cantidad de observaciones a mostrar
    display_rows <- floor(sqrt(m)) #10
    display_cols <- ceiling(m / display_rows) #10
           
    # Espaciado entre imágenes
    pad <- 1

    display_array <- -matrix(0,pad + display_rows * (example_height + pad), pad + display_cols * (example_width + pad))
    curr_ex <- 1

    for (j in 1:display_rows) {
        for (i in 1:display_cols) {
          if (curr_ex > m)
            break
      
          max_val <- max(abs(X[curr_ex,]))
          display_array[pad + (j - 1) * (example_height + pad) + (1:example_height), pad + (i - 1) * (example_width + pad) + 
                        (1:example_width)] <- matrix(unlist(X[curr_ex,]), example_height, example_width) / max_val
          curr_ex <- curr_ex + 1
        }
    
        if (curr_ex > m)
          break
    }

    # Mostrar imagen
    op <- par(bg = "gray")

    #La imagen se dibuja por fila de abajo a arriba, pero R indexa las matrices por columnas, de arriba a abajo
    dispArr <- t(apply(display_array,2,rev))

    image(z = dispArr, col = gray.colors(100), xaxt = 'n', yaxt = 'n')

    grid(nx = display_cols, display_rows, col = 'black', lwd = 2, lty = 1)
    box()
    par(op)
    
}
        

displayData(sel)
# Out:
# plot without title

# %%
#Antes de realizar PCA debemos escalar los datos.
X_norm <- scale(X)
str(X_norm)
dim(X_norm)
# Out:
#  num [1:5000, 1:1024] -0.315 0.584 -0.217 -1.234 0.467 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : NULL
#   ..$ : chr [1:1024] "X.1" "X.2" "X.3" "X.4" ...
#  - attr(*, "scaled:center")= Named num [1:1024] -21.7 -20.8 -19.7 -18.6 -17.7 ...
#   ..- attr(*, "names")= chr [1:1024] "X.1" "X.2" "X.3" "X.4" ...
#  - attr(*, "scaled:scale")= Named num [1:1024] 51.2 50.4 49.5 48.9 48.3 ...
#   ..- attr(*, "names")= chr [1:1024] "X.1" "X.2" "X.3" "X.4" ...
# [1] 5000 1024

# %%
#Ejecutamos el algoritmo PCA

pca <- function(X) {
    
    m <- nrow(X)
    n <- ncol(X)
    
    U <- rep(0, n)
    S <- rep(0, n)
    
    #Calculamos la matriz de covarianza
    Sigma <- (1 / m) * (t(X) %*% X) # matriz nxn
    
    USV <- svd(Sigma)
    
    return(USV)
}

USV <- pca(X_norm)

#U contiene el componente principal, S($d en este caso) contiene la matriz diagonal
S <- USV$d
U <- USV$u

# %%
#Visualizamos los 36 eigenvectores superiores
displayData(t(U[, 1:36]))
# Out:
# plot without title

# %%
#Reducción de dimensionalidad sobre imágenes

#Usaremos 100 eigenvectores es decir, el dataset original lo proyectaremos a 100 (reducción de 1024 a 100)

K <- 100

projectData <- function(X, U, K) {
    
    
    Z <- matrix(0, nrow = nrow(X), ncol = K)
    U_reduce <- U[,1:K]
    
    Z <- X %*% U_reduce #o t(U_reduce) %*% X    si X es una matriz y no un dataframe
    
    Z    
}

Z <- projectData(X_norm, U, K)
str(Z) #Los datos proyectados ahora tienen una dimensión de 5000 x 100
# Out:
#  num [1:5000, 1:100] 15.11 9.95 -7.7 21.82 29.18 ...

# %%
#Visualización de las imágenes luego de la reducción con PCA
K <- 100

recoverData <- function(Z, U, K) {
    
    X_rec <- matrix(0, nrow(Z), length(K))
    U_reduce <- U[,1:K]
    X_rec <- Z %*% t(U_reduce)
    X_rec
}

X_rec <- recoverData(Z, U, K)
str(X_rec)
dim(X_rec)
# Out:
#  num [1:5000, 1:1024] -0.24 0.298 -0.184 -0.562 0.303 ...
# [1] 5000 1024

# %%
cat("Rostros originales:")
displayData(X_norm[1:100,])
# Out:
# Rostros originales:
# plot without title

# %%
cat("Rostros recuperados:")
displayData(X_rec[1:100,])
# Out:
# Rostros luego de la compresión:
# plot without title
