# %%
#Text mining Properati Dataset (www.properati.com.ar)

# %%
#Instalación de paquetes
list.of.packages <- c('tm', 'wordcloud')

new.packages <- list.of.packages[!(list.of.packages %in% 
                                   installed.packages()[,"Package"])]

if(length(new.packages)) install.packages(new.packages, 
                                          repos = "https://cran.r-project.org")

library(tm)
library(wordcloud)
    
#Configuraciones adicionales
options(warn=-1, scipen = 999, repr.plot.width=7, repr.plot.height=5)
# Out:
# Loading required package: NLP
# Loading required package: RColorBrewer

# %%
#Carga de datos
load("data/properati-rent.Rda")

# %%
properati <- df[, c('place_name', 'title', 'description')]

# %%
str(properati)
# Out:
# 'data.frame':	22297 obs. of  3 variables:
#  $ place_name : chr  "Quilmes" "Tigre" "Quilmes" "Tigre" ...
#  $ title      : chr  "Imperdible" "ph 3 amb talar a 2 de colectora" "Precio Increible!!!!!" "ALQUILER" ...
#  $ description: chr  ".Publicado por EDUARDO RODRIGUEZ PROPIEDADES a traves INMOMAP" ".Publicado por Herrera &amp; Cia a traves INMOMAP" ".Publicado por Servicios Profesionales Alvarez Casal a traves INMOMAP" "CASA CENTRO DE BENAVIDEZ CON GAS NATURAL SIN COCHERA CON PIELTA .Publicado por piperse a traves INMOMAP" ...

# %%
properati$text <- paste0(properati$title, properati$description)

# %%
properati[, c('title', 'description')] <- NULL

# %%
str(properati)
# Out:
# 'data.frame':	22297 obs. of  2 variables:
#  $ place_name: chr  "Quilmes" "Tigre" "Quilmes" "Tigre" ...
#  $ text      : chr  "Imperdible.Publicado por EDUARDO RODRIGUEZ PROPIEDADES a traves INMOMAP" "ph 3 amb talar a 2 de colectora.Publicado por Herrera &amp; Cia a traves INMOMAP" "Precio Increible!!!!!.Publicado por Servicios Profesionales Alvarez Casal a traves INMOMAP" "ALQUILERCASA CENTRO DE BENAVIDEZ CON GAS NATURAL SIN COCHERA CON PIELTA .Publicado por piperse a traves INMOMAP" ...

# %%
tail(properati)
# Out:
#       place_name
# 22292 Vicente López
# 22293 Palermo
# 22294 Palermo
# 22295 Bs.As. G.B.A. Zona Norte
# 22296 San Isidro
# 22297 Belgrano
#       text
# 22292 Departamento con Plantas en Miguel De Azcuénaga 1200, Bs.As. G.B.A. Zona Norte, Vicente López, por $ 16.500Muy buen departamento<br><br>Hall, living comedor, estar Ã­ntimo, cocina, dep. servicio, 3 dormitorios, 2 baÃ±os.<br>Calefactores en dormitorios y living-comedor. Agua caliente por 2 calefones.<br>OrientaciÃ³n: frente nor-este. BalcÃ³n con vista al rÃ­o.Cochera. Baulera.<br><br>Expensas $ 3105<br> A.B.L. $ 357<br><br>[ Dixon9801043 ]
# 22293 Departamento 49m² con Cochera en Arevalo 3000, Capital Federal, Palermo, por $ 14.000Excelente y moderno departamento de 2 ambientes al frente, tercer piso, muy luminoso, en el Complejo Terrazas al Polo, la mejor zona de CaÃ±itas. <br>EdificaciÃ³n nueva (antigÃ¼edad 3 aÃ±os) de 4 pisos con detalles de categorÃ­a del Estudio Gradel Kopellioff; terminaciones de calidad. <br>Dormitorio con placard espejado. <br>Cocina completa, con mesada de marmol. ConexiÃ³n para lavarropas o lavavajillas. <br>BaÃ±o completo <br>CalefacciÃ³n por losa radiante. Pisos flotantes. <br>Seguridad 24 hs y estacionamiento de cortesÃ­a. <br>Amenities: Gimnasio, Sum, Sala de masajes, Sauna, Laundry, Parrillas, Yacuzzi, Solarium y gran pileta climatizada de 22 metros. <br>Expensas: 3800$<br>Las medidas son aproximadas y al solo efecto orientativo. Las medidas reales surgen del titulo de propiedad.<br><br>[ Dixon72700150 ]
# 22294 Departamento 87m² con Cochera en Arevalo 3000, Capital Federal, Palermo, por $ 21.000Excelente y moderno departamento, de 3 ambientes al frente, tercer piso, muy luminoso, en el Complejo Terrazas al Polo, la mejor zona de CaÃ±itas. <br>EdificaciÃ³n nueva (antigÃ¼edad 4 aÃ±os) de 4 pisos con detalles de categorÃ­a del Estudio Gradel Kopellioff; terminaciones de calidad. <br>Dos dormitorios con placards. <br>Cocina completa, con mesada de marmol. ConexiÃ³n para lavarropas o lavavajillas. <br>Dos BaÃ±os. <br>CalefacciÃ³n por losa radiante. Pisos flotantes. <br>Seguridad 24 hs y estacionamiento de cortesÃ­a. <br>Amenities: Gimnasio, Sum, Sala de masajes, Sauna, Laundry, Parrillas, Yacuzzi, Solarium y gran pileta climatizada de 22 metros. <br>Expensas: 6800$<br>Las medidas son aproximadas y al solo efecto orientativo. Las medidas reales surgen del titulo de propiedad.<br><br>[ Dixon72700152 ]
# 22295 Departamento 76m² con Teléfono, Argentina, Bs.As. G.B.A. Zona Norte, por $ 13.000Libre 1 de Enero 2017<br>Muy buen depto. en 3Â° piso en Jardines de San Isidro II.<br><br>Living-comedor con salida al balcÃ³n. Cocina con lavadero incorporado.<br>Dos dormitorios, uno en suite, un baÃ±o completo mÃ¡s. Techos altos!<br>Mira hacia la pileta. Cochera doble con baulera.<br><br>Expensas: $ 4.800 (incluyen AYSA) ABL: $ 770<br><br>El Condominio cuenta con seguridad las 24 hs, pileta para niÃ±os, laundry, sauna, etc.<br><br>[ Dixon1102239 ]
# 22296 Local con Teléfono en Juan José Díaz 500, Bs.As. G.B.A. Zona Norte, San Isidro, por $ 10.000Necesita algunas reparaciones<br>Posibilidad de Armar un Local en San Isidro Centro a una cuadra de Tribunales San Isidro<br>Desarrollado en 2 Plantas de unos 15 m2 cubiertos cada una. Un baÃ±o en planta baja<br>Actualmente se accede a la planta alta por una escalera externa<br><br>[ Dixon10204661 ]
# 22297 Departamento 90m² con Cochera en Juramento 3100, Capital Federal, Belgrano, por $ 14.000Muy linda vista y mucha luz. Reciclado.<br>Living comedor, toilette, 3 dormitorios, baÃ±o completo, cocina, lavadero.<br>El edificio tiene SUM, patio de uso comÃºn<br><br>[ Dixon45400911 ]

# %%
#Quitar las etiquetas html
cleanFun <- function(htmlString) {
  return(gsub("<.*?>", "", htmlString))
}

properati$text <- cleanFun(properati$text)
properati$text <- iconv(properati$text, from  = 'UTF-8')
properati$place_name <- iconv(properati$place_name, from = 'UTF-8')

# %%
head(properati)
# Out:
#   place_name
# 1 Quilmes
# 2 Tigre
# 3 Quilmes
# 4 Tigre
# 5 Tigre
# 6 La Matanza
#   text
# 1 Imperdible.Publicado por EDUARDO RODRIGUEZ PROPIEDADES a traves INMOMAP
# 2 ph 3 amb talar a 2 de colectora.Publicado por Herrera &amp; Cia a traves INMOMAP
# 3 Precio Increible!!!!!.Publicado por Servicios Profesionales Alvarez Casal a traves INMOMAP
# 4 ALQUILERCASA CENTRO DE BENAVIDEZ CON GAS NATURAL SIN COCHERA CON PIELTA .Publicado por piperse a traves INMOMAP
# 5 ALQUILODEPARTAMENTO CENTRICO NO SE ADMITEN MASCOSTAS SIN COCHERA, SIN GAS NATURAL .Publicado por piperse a traves INMOMAP
# 6 DPTO 2 AMBIENTES A ESTRENAR!Departamento a Estrenar de 2 ambientes 1 Dormitorio, Cocina, Comedor, Bao. Cualquier duda consultenos! al  .Publicado por Masu a traves INMOMAP

# %%
properati <- aggregate(text ~ place_name, data = properati, paste0)

# %%
myReader <- readTabular(mapping=list(content="text", id="place_name"))
corpus_clean <- VCorpus(DataframeSource(properati), readerControl=list(reader=myReader))

# %%
for (i in 1:length(corpus_clean)) {
  attr(corpus_clean[[i]], "place_name") <- properati$place_name[i]
}

# %%
#Stop words en castellano
es_words <- readLines("data/words.txt")

#Tambien quito las palabras que esten en el nombre del lugar porque reaparecen varias veces en 
#el titulo o la descripcion por lo que resultará en una palabra frecuente y no queremos eso
split_words <- function(x){ strsplit(x, "[^[:alpha:]]+") }
places_words <- tolower(unlist(lapply(properati$place_name, split_words)))

# %%
#Limpiar texto
skip_es_words <- function(x) removeWords(x, es_words)
skip_place_words <- function(x) removeWords(x, places_words)
funcs <- list(content_transformer(tolower), removePunctuation, removeNumbers, stripWhitespace, skip_es_words, skip_place_words)
corpus_clean <- tm_map(corpus_clean, FUN = tm_reduce, tmFuns = funcs)
corpus_clean <- tm_map(corpus_clean, removeWords, stopwords('es'))
corpus_clean <- tm_map(corpus_clean, removeWords, c("alquilo", "alquiler", "alq", 'depto', 'dpto', 'casa', 'departamento', 'ambientes', 'local', 'ambiente', 'excelente', 'apto'))

# %%
#Armo el DTM
dtm <- DocumentTermMatrix(corpus_clean, control = list(wordLengths = c(4,17))) #limito a palabras entre 4 y 17 caracteres

rowTotals <- apply(dtm , 1, sum)
dtm <- dtm[rowTotals > 0, ] 

colTotals <- apply(dtm, 2, sum)
dtm <- dtm[,colTotals > 20]

tst <- apply(dtm, 1, function(x) unlist(dtm[["dimnames"]][2], use.names = FALSE)[x == max(x)])

# %%
#Buscar lugars con palabra mas frecuente "Subte"
idx <- grep('subte', tst)
tst[idx]

# %%
#Mostrar todos los lugares y sus palabras más frecuentes
# Out:
# $`9 de Abril`
# [1] "amoblada" "quinta"
#
# $Abasto
# [1] "cocina"
#
# $`Abril Club de Campo`
# [1] "baño"
#
# $`Acacias Blancas`
# [1] "baño"
#
# $Acassuso
# [1] "acassuso"
#
# $Adrogué
# [1] "baño"
#
# $`Aeropuerto Internacional Ezeiza`
# [1] "pisos"
#
# $Agronomía
# [1] "expensas"
#
# $`Albanueva Barrio Cerrado`
# [1] "albanueva"
#
# $`Aldea Protestante`
# [1] "amplio"     "comedor"    "parquizado" "terreno"
#
# $`Aldo Bonzi`
# [1] "publicado"
#
# $Alfar
# [1] "camas"
#
# $Almagro
# [1] "cuadras"
#
# $`Almirante Brown`
# [1] "comercial" "publicado"
#
# $`Alta Gracia`
# [1] "dormitorios"
#
# $Altamira
# [1] "negocios"  "oficina"   "propiedad" "venta"
#
# $`Altos de Hudson I`
# [1] "altos"
#
# $`Altos de Hudson II`
#  [1] "alquilerventa" "altos"         "baño"          "flotante"
#  [5] "fríocalor"     "goldoni"       "jacuzzi"       "parrilla"
#  [9] "pisos"         "porcelanato"   "propiedades"   "recepción"
# [13] "suite"
#
# $`Altos de Manzanares 1 y 2`
# [1] "roca"
#
# $Anisacate
# [1] "baño"        "cama"        "cocina"      "dormitorios" "propiedad"
# [6] "ropero"
#
# $Añelo
# [1] "dormitorios"   "frente"        "habitaciones"  "hotel"
# [5] "inmobiliarias" "inversiones"   "ruta"          "solar"
# [9] "urbano"
#
# $Apóstoles
# [1] "publicado"
#
# $Ascochinga
# [1] "asador"
#
# $Avellaneda
# [1] "cocina" "pisos"  "precio"
#
# $Azul
# [1] "publicado"
#
# $`Bahía Blanca`
# [1] "baño"
#
# $Balcarce
# [1] "dormitorios"
#
# $Balvanera
# [1] "propiedades"
#
# $Banfield
# [1] "baño"
#
# $Baradero
# [1] "publicado"
#
# $`Barbarita, Barrio Cerrado`
# [1] "baño"         "comedor"      "habitaciones"
#
# $Barracas
# [1] "comercial"
#
# $`Barrancas de Santa María`
# [1] "lago"
#
# $`Barrio Alamo Alto`
# [1] "madera"     "mooswalder" "negocios"
#
# $`Barrio Cabos del Lago`
# [1] "área" "lago"
#
# $`Barrio Cerrado`
# [1] "duplex"
#
# $`Barrio Cerrado ""Soles de Pilar""`
# [1] "pilar"
#
# $`Barrio Cerrado El Lauquén`
# [1] "amueblada"  "familias"   "lauquen"    "permanente"
#
# $`Barrio Cerrado Los Troncos`
# [1] "publicado"
#
# $`Barrio El Golf`
# [1] "lago"
#
# $`Barrio El Yacht`
# [1] "cmcpsi"  "comedor"
#
# $`Barrio La Alameda`
# [1] "dormitorios"
#
# $`Barrio La Isla`
# [1] "planta" "salida"
#
# $`Barrio Lagos del Golf 2`
# [1] "aires"    "complejo" "mansa"    "vidrio"   "vista"
#
# $`Barrio Las Glorietas`
# [1] "baño"
#
# $`Barrio Los Alisos`
# [1] "baño"        "comedor"     "dormitorios"
#
# $`Barrio Los Castores`
# [1] "baño"
#
# $`Barrio Los Jazmines - Pilar del Este`
# [1] "comedor"
#
# $`Barrio Los Sauces`
# [1] "comedor"     "dormitorios" "sauces"
#
# $`Barrio Norte`
# [1] "cocina"
#
# $`Barrio Parque General San Martin`
# [1] "propiedades"
#
# $`Barrio Privado ""Ayres de Pilar""`
# [1] "acceso" "baño"
#
# $`Barrio Privado Altos del Sol`
# [1] "placard" "planta"
#
# $`Barrio Privado El Rodal`
# [1] "barrio"
#
# $`Barrio Privado María Eugenia`
# [1] "baño"     "central"  "completo" "piso"
#
# $`Barrio Privado Villa Olivos`
# [1] "barrio"      "dormitorios" "niños"
#
# $`Barrio San Agustin`
# [1] "amplio"      "aprox"       "baño"        "completo"    "condiciones"
# [6] "jardín"      "planta"
#
# $`Barrio San Francisco`
#  [1] "baño"        "cocina"      "comedor"     "compartido"  "construida"
#  [6] "dormitorios" "imperdible"  "jardín"      "linda"       "lindo"
# [11] "living"      "pileta"      "planta"      "principal"   "suite"
# [16] "toilette"
#
# $`Barrio San Isidro Labrador`
# [1] "temporada"
#
# $`Barrio San Juan`
# [1] "calle"  "vereda"
#
# $`Barrio Santa Clara`
#  [1] "aparte"      "cochera"     "comedor"     "completo"    "cubierta"
#  [6] "dormitorios" "expensas"    "gran"        "incluyen"    "inmejorable"
# [11] "laguna"      "living"      "nueva"       "pileta"      "piletero"
# [16] "santa"       "separado"    "tamaño"      "temporario"  "toilette"
# [21] "valores"     "vista"       "yacuzzi"
#
# $`Barrio Santa Teresa`
# [1] "barra"      "comedor"    "protección"
#
# $BarrioPortezuelo
# [1] "vista"
#
# $Beccar
# [1] "beccar"
#
# $`Belén de Escobar`
# [1] "cocina"  "escobar"
#
# $Belgrano
# [1] "cocina"
#
# $`Bell Ville`
# [1] "propiedades" "tucumán"
#
# $`Bella Vista`
# [1] "publicado"
#
# $Benavidez
# [1] "comedor"
#
# $Berazategui
# [1] "baño"
#
# $`Berazategui Oeste`
# [1] "calle"       "campostrini" "mariano"
#
# $Berisso
# [1] "dormitorio"
#
# $`Bermudas Country Club`
# [1] "pilar"
#
# $Bernal
# [1] "publicado"
#
# $Billinghurst
# [1] "propiedades"
#
# $`Boat Center Barrio Cerrado`
# [1] "suite"
#
# $Boca
# [1] "metros"
#
# $`Boca Ratón`
# [1] "boca"
#
# $Boedo
# [1] "boedo"
#
# $`Bosque Peralta Ramos`
# [1] "antebaño" "baño"     "deposito"
#
# $Brandsen
# [1] "baño"         "habitaciones" "publicado"
#
# $`Bs.As. G.B.A. Zona Norte`
# [1] "zona"
#
# $`Bs.As. G.B.A. Zona Sur`
# [1] "amplio"      "calle"       "cocina"      "propiedades" "semestre"
# [6] "vivani"
#
# $`Buena Nueva`
# [1] "baño"        "barrio"      "blanca"      "comedor"     "dormitorios"
# [6] "privado"     "propiedades" "publicado"   "torre"
#
# $`Buenos Aires Costa Atlántica`
# [1] "alquileralquiler" "blanca"           "macagno"          "propiedades"
#
# $`Buenos Aires Interior`
# [1] "cocina"
#
# $Burzaco
# [1] "publicado"
#
# $Caballito
# [1] "cocina"
#
# $`Caleta Olivia`
# [1] "baño"         "dormitorios"  "duplex"       "estrenar"     "inmobiliaria"
# [6] "interno"      "patio"        "publicado"
#
# $Campana
# [1] "baño"    "campana"
#
# $`Campo Chico Country Club`
# [1] "cancha"
#
# $`Campo Grande`
# [1] "ruta"
#
# $Candelaria
# [1] "cuadra"      "dormitorios"
#
# $Canning
# [1] "canning"
#
# $Cañuelas
# [1] "publicado" "quinta"
#
# $`Capital Federal`
# [1] "publicado"
#
# $`Capitán Sarmiento`
# [1] "comercial"     "inmobiliarios" "negocios"
#
# $Carapachay
# [1] "semestre"
#
# $`Cardales Country Club`
# [1] "barrio"  "entrada" "sector"  "village"
#
# $Cariló
# [1] "dormitorios" "suite"
#
# $`Carlos Casares`
# [1] "carlos"
#
# $`Carmen de Areco`
# [1] "zona"
#
# $`Carmen de Patagones`
# [1] "colon"     "duplex"    "estrenar"  "publicado"
#
# $Caseros
# [1] "cocina"
#
# $Castelar
# [1] "castelar"
#
# $Castellanos
# [1] "santa"
#
# $Catalinas
# [1] "peatonal"
#
# $Centenario
# [1] "house"
#
# $Centeno
# [1] "santa"
#
# $Centro
# [1] "calle"
#
# $`Centro / Microcentro`
# [1] "propiedades"
#
# $Cerrillos
# [1] "castañeda"   "comercial"   "cucis"       "pablo"       "responsable"
#
# $Chacarita
# [1] "cocina"
#
# $Chamical
# [1] "publicado"
#
# $Chascomús
# [1] "celular"
#
# $Chivilcoy
# [1] "agua"        "entrepiso"   "instalación"
#
# $`Choele Choel`
# [1] "publicado"
#
# $Cipolletti
# [1] "house"
#
# $`City Bell`
# [1] "dormitorios"
#
# $`Ciudad Evita`
# [1] "propiedades"
#
# $`Ciudad Jardín Lomas del Palomar`
# [1] "publicado"
#
# $Ciudadela
# [1] "publicado"
#
# $Claromecó
# [1] "arroyo"  "cuadras" "leña"    "rivera"  "vista"
#
# $Claypole
# [1] "publicado" "recibo"    "sueldo"
#
# $`Club de Campo Las Perdices`
# [1] "campo"    "cocina"   "estilo"   "mesada"   "parrilla"
#
# $Coghlan
# [1] "cocina"
#
# $Colegiales
# [1] "cocina"
#
# $Colón
# [1] "publicado" "ruta"      "ubicado"
#
# $`Colonia Caroya`
# [1] "colonia"
#
# $`Colonia Tirolesa`
# [1] "colonia"
#
# $`Comodoro Rivadavia`
# [1] "inmobiliaria"
#
# $`Concepción del Uruguay`
# [1] "publicado"
#
# $Concordia
# [1] "inmobiliaria" "palma"
#
# $Confluencia
# [1] "comercial"
#
# $Congreso
# [1] "publicado"
#
# $Constitución
# [1] "calle"
#
# $Córdoba
# [1] "cocina"
#
# $Coronda
# [1] "lópez"
#
# $`Coronel Brandsen`
# [1] "alquilar" "baños"    "cochera"  "estrenar" "estudio"  "parrilla" "ruta"
# [8] "yacoub"
#
# $`Coronel Suárez`
# [1] "marcalain"   "propiedades"
#
# $Corrientes
# [1] "publicado"
#
# $`Costa Azul`
# [1] "monoambiente"
#
# $`Costa Esmeralda`
# [1] "quincena"
#
# $`Country Banco Provincia`
# [1] "expensas"  "jardinero" "piletero"
#
# $`Country Club Aranjuez`
# [1] "comedor"   "contrato"  "country"   "pileta"    "propiedad"
#
# $`Country Club Las lajas`
# [1] "amplio"    "publicado"
#
# $`Country Farm Club`
# [1] "amplia"     "comedor"    "dormitorio" "frente"     "pilar"
# [6] "suite"
#
# $`Country Golf El Sosiego`
#  [1] "actividades" "cama"        "chicos"      "cocina"      "futbol"
#  [6] "golf"        "juegos"      "lote"        "pisos"       "salón"
# [11] "vida"
#
# $`Country Maschwitz Club`
# [1] "publicado"
#
# $`Country Maschwitz Privado`
# [1] "comedor"   "cubierta"  "maschwitz"
#
# $`Country San Jorge Village`
# [1] "grande"
#
# $Cushamen
# [1] "semana"
#
# $`Del Viso`
# [1] "pilar"
#
# $Delta
# [1] "castilla"
#
# $Derqui
# [1] "monoambiente"
#
# $Desamparados
# [1] "cocina"
#
# $`Dique Luján`
# [1] "acceso" "precio"
#
# $`Dock Sud`
#  [1] "alem"      "calle"     "celular"   "cortina"   "frente"    "grupo"
#  [7] "impuestos" "mayo"      "servicios" "whatsapp"
#
# $`Don Bosco`
# [1] "baño"
#
# $`Don Torcuato`
# [1] "comedor" "tigre"
#
# $Dorrego
# [1] "dorrego"
#
# $`Echeverría del Lago`
# [1] "echeverria"
#
# $`El Calafate`
# [1] "publicado"
#
# $`El Encuentro`
# [1] "cocina" "pileta"
#
# $`El Jagüel`
# [1] "publicado"
#
# $`El Nacional Club de Campo`
# [1] "golf"
#
# $`El Palomar`
# [1] "publicado"
#
# $`El Remanso`
# [1] "gran"    "piscina"
#
# $`El Rocío`
# [1] "planta" "suite"
#
# $`El Talar`
# [1] "medidas"
#
# $`El Talar de Pacheco`
# [1] "baño"
#
# $`El Volcán`
#  [1] "alquilerhermoso" "amoblada"        "baño"            "bosques"
#  [5] "cochera"         "cocina"          "comedor"         "dormitorio"
#  [9] "entrepiso"       "grande"          "living"          "luis"
# [13] "natación"        "pileta"          "plantas"         "propiedades"
# [17] "recepción"       "semi"            "suite"           "totalmente"
# [21] "ubicada"         "usos"
#
# $`El Zorzal`
# [1] "baño"    "galería" "planta"  "salida"
#
# $`Empalme Villa Constitución`
# [1] "recibo" "sueldo"
#
# $Ensenada
# [1] "comedor" "planta"  "plata"
#
# $`Entre Ríos`
# [1] "dormitorio"
#
# $Enyoi
#  [1] "alquilerexcelente" "balcon"            "block"
#  [4] "cocina"            "dixon"             "enorme"
#  [7] "expensas"          "habitaciones"      "increible"
# [10] "lavadero"          "pena"              "piso"
# [13] "placares"          "tercer"            "verlo"
# [16] "vista"
#
# $Escobar
# [1] "maschwitz"
#
# $Esperanza
# [1] "cocina"
#
# $Esquel
# [1] "pixelinmobiliario" "publicado"
#
# $`Estancias del Pilar`
# [1] "baño"     "gastos"   "internet" "parrilla" "pileta"
#
# $`Esteban Echeverría`
# [1] "publicado"
#
# $`Exaltación de la Cruz`
# [1] "campo"
#
# $Ezeiza
# [1] "publicado"
#
# $Ezpeleta
# [1] "publicado"
#
# $Fátima
# [1] "baño"
#
# $`Fincas de Hudson`
# [1] "amplio" "doble"  "polo"
#
# $`Fincas de Iraola II`
# [1] "calles"     "dormitorio"
#
# $`Florencio Varela`
# [1] "campostrini" "florencio"   "mariano"     "varela"
#
# $Flores
# [1] "publicado"
#
# $Floresta
# [1] "baño"   "cocina"
#
# $Florida
# [1] "florida"
#
# $`Florida Oeste`
# [1] "florida"
#
# $`Francisco Alvarez`
# [1] "propiedades" "publicado"
#
# $`Fray Luis Beltrán`
# [1] "dormitorios"  "inmobiliaria" "luis"         "mendoza"
#
# $Funes
# [1] "baño"        "comedor"     "dormitorios"
#
# $Garín
# [1] "publicado"
#
# $Garupá
# [1] "frente"
#
# $`General Belgrano`
# [1] "dormitorio"
#
# $`General Pacheco`
# [1] "medidas"
#
# $`General Pico`
# [1] "servicios"
#
# $`General Pueyrredón`
# [1] "parque"   "parrilla" "vista"
#
# $`General Roca`
# [1] "comercial"
#
# $`General Rodríguez`
# [1] "metros"
#
# $`General San Martín`
# [1] "publicado"
#
# $Gerli
# [1] "baño"
#
# $Glew
# [1] "publicado"
#
# $`Godoy Cruz`
# [1] "espacio"         "estacionamiento" "exclusivo"       "imperio"
# [5] "inmobiliaria"    "martin"          "publicado"
#
# $`González Catán`
# [1] "baño"
#
# $`Granadero Baigorria`
# [1] "baño"
#
# $`Grand Bourg`
# [1] "publicado"
#
# $`GreenVille Polo & Resort`
# [1] "comercial"
#
# $`Gregorio de Laferrere`
# [1] "pisos"
#
# $Gualeguaychú
# [1] "publicado"
#
# $Güemes
# [1] "dormitorio"  "dormitorios"
#
# $Guernica
# [1] "publicado"
#
# $`Guillermo Hudson`
# [1] "goldoni"     "guillermo"   "propiedades"
#
# $Gutierrez
# [1] "bosque"  "canchas"
#
# $Haedo
# [1] "haedo"
#
# $`Haras del Pilar - El Establo`
# [1] "baño"
#
# $`Haras del Pilar - La Caballeriza`
# [1] "haras"     "publicado"
#
# $`Haras del Pilar - Las Praderas 1 y 2`
# [1] "gran"
#
# $`Haras del Sur II`
# [1] "baja"   "haras"  "niños"  "planta"
#
# $`Haras María Elena`
# [1] "alfombra" "bañera"   "baño"     "placard"
#
# $`Haras María Victoria`
# [1] "bienes"
#
# $`Haras Santa Maria`
# [1] "haras" "santa"
#
# $Humboldt
# [1] "locales"
#
# $Hurlingham
# [1] "publicado"
#
# $`Ingeniero Adolfo Sourdeaux`
# [1] "publicado"
#
# $`Ingeniero Juan Allan`
#  [1] "alquila"         "amplio"          "capacidad"       "cocina"
#  [5] "estacionamiento" "familiares"      "florencio"       "infantiles"
#  [9] "ingeniero"       "mesada"          "mesas"           "personas"
# [13] "publicado"       "quincho"         "tarifa"          "ubicado"
#
# $`Ingeniero Pablo Nogués`
# [1] "pileta"
#
# $Iriondo
# [1] "solares"
#
# $`Isidro Casanova`
# [1] "publicado"
#
# $`Islas del Canal`
# [1] "barrio" "canal"  "islas"
#
# $Ituzaingó
# [1] "baño"
#
# $`José C Paz`
# [1] "publicado"
#
# $`José Ingenieros`
# [1] "francisco" "general"   "inmuebles" "mesada"
#
# $`Jose Leon Suarez`
# [1] "jose"
#
# $`Jose Marmol`
# [1] "fondo"     "jorge"     "publicado" "ubicado"
#
# $`Juana Koslay`
# [1] "baño"
#
# $`La Arboleda de Maschwitz`
# [1] "inmobiliaria" "inmomap"      "linda"        "traves"
#
# $`La Calera`
# [1] "ruta"
#
# $`La Cumbre`
# [1] "cocina"  "piso"    "ubicado"
#
# $`La Dormida`
# [1] "dormitorios"
#
# $`La Falda`
# [1] "categoría"    "chalet"       "monoambiente"
#
# $`La Granja`
# [1] "baño"
#
# $`La Lomada de Pilar`
# [1] "baño"    "comedor"
#
# $`La Lonja`
#  [1] "auto"       "cocina"     "comedor"    "completo"   "cubiertos"
#  [6] "disponible" "dixon"      "dormitorio" "duplex"     "frente"
# [11] "integrada"  "jardin"     "living"     "pilar"      "retiro"
# [16] "teléfono"
#
# $`La Lucila`
# [1] "lucila"
#
# $`La Lucila del Mar`
# [1] "costa"
#
# $`La Madrugada`
# [1] "cocina"
#
# $`La Matanza`
# [1] "publicado"
#
# $`La Pampa`
# [1] "publicado"
#
# $`La Peregrina`
# [1] "baño"    "comedor"
#
# $`La Perla`
# [1] "baño"        "cocina"      "dormitorios" "piso"        "vista"
#
# $`La Plata`
# [1] "cocina"
#
# $`La Punta`
# [1] "superficie"
#
# $`La Reja`
# [1] "publicado"
#
# $`La Rioja`
# [1] "centro"
#
# $`La Tablada`
# [1] "publicado"
#
# $`La Unión`
# [1] "cinco"     "cuadra"    "cuadras"   "publicado"
#
# $Lácar
# [1] "andes"
#
# $`Laguna del Sol`
# [1] "muebles"
#
# $Lamarque
# [1] "precio"
#
# $Lanús
# [1] "meses"
#
# $`Lanús Este`
# [1] "propiedades"
#
# $`Lanús Oeste`
# [1] "publicado"
#
# $`Las Cañitas`
# [1] "cañitas"
#
# $`Las Gaviotas`
# [1] "unidades"
#
# $`Las Heras`
# [1] "dormitorios" "llamar"      "publicado"   "sueldo"
#
# $`Las Palmas`
# [1] "complejo"
#
# $`Las Toninas`
# [1] "cuadras"     "inmomap"     "paolo"       "propiedades" "publicado"
# [6] "traves"
#
# $Libertad
# [1] "merlo"
#
# $Lincoln
# [1] "alem"
#
# $Liniers
# [1] "publicado"
#
# $`Lisandro Olmos`
# [1] "consulte" "estrenar" "frente"   "persiana"
#
# $Llavallol
# [1] "comedor"
#
# $Lobos
# [1] "quincena" "quinta"
#
# $`Loma Hermosa`
# [1] "edificio"
#
# $`Loma Verde`
# [1] "baño"
#
# $`Lomas de Zamora`
# [1] "baño"
#
# $`Lomas del Mirador`
# [1] "publicado"
#
# $Longchamps
# [1] "publicado"
#
# $`Los Cardales`
# [1] "completo"
#
# $`Los Hornos`
# [1] "agua"       "baño"       "cocina"     "comedor"    "consta"
# [6] "dormitorio" "incluidos"  "patio"      "servicios"
#
# $`Los Lagartos Country Club`
# [1] "canchas"
#
# $`Los Polvorines`
# [1] "publicado"
#
# $`Los Reartes`
# [1] "baño"        "dormitorio"  "dormitorios" "lavalle"     "publicado"
# [6] "vivienda"
#
# $`Los Sauces Country Club`
# [1] "amplio" "baño"   "cancha" "planta"
#
# $`Luis Guillón`
# [1] "publicado" "ubicado"
#
# $Luján
# [1] "baño"
#
# $`Luján de Cuyo`
# [1] "cocina" "madera"
#
# $Macrocentro
#  [1] "alta"      "antebaño"  "baño"      "baños"     "belgrano"  "estrenar"
#  [7] "pisos"     "planta"    "propiedad" "zona"
#
# $Maipú
# [1] "salón"
#
# $`Malvinas Argentinas`
# [1] "comedor"
#
# $Manantiales
# [1] "dormitorios"
#
# $`Manuel Alberti`
# [1] "sector"
#
# $`Manuel B Gonnet`
# [1] "baño"        "belgrano"    "dormitorios" "entrepiso"   "negocios"
# [6] "yacoub"
#
# $Manzanares
# [1] "baño"
#
# $`Mapuche Country Club`
# [1] "baño"
#
# $`Mar Azul`
# [1] "azul"
#
# $`Mar Chiquita`
# [1] "enero"
#
# $`Mar de Ajó`
# [1] "quincena"
#
# $`Mar de las Pampas`
# [1] "diarios"
#
# $`Mar del Plata`
# [1] "baño"
#
# $`Mar del Sur`
# [1] "dormitorios"
#
# $`Mar del Tuyú`
# [1] "publicado"
#
# $`Marcos Paz`
# [1] "publicado"
#
# $`Marinas Golf Barrio Cerrado`
# [1] "comedor"
#
# $`Martín Coronado`
# [1] "propiedades"
#
# $`Martindale Country Club`
# [1] "dormitorios"
#
# $Martínez
# [1] "comedor"
#
# $Maschwitz
# [1] "publicado"
#
# $Mataderos
# [1] "baño"
#
# $Materno
# [1] "baño"
#
# $Matheu
# [1] "publicado"
#
# $`Mayling Club de Campo`
# [1] "baño"
#
# $Mendiolaza
# [1] "comedor"
#
# $Mendoza
# [1] "cocina"
#
# $Mercedes
# [1] "calle"    "estrenar" "metros"
#
# $Merlo
# [1] "merlo"
#
# $`Mina Clavero`
# [1] "publicado"
#
# $`Miraflores Country Club`
# [1] "club"   "house"  "planta"
#
# $Miramar
# [1] "cocina"
#
# $Misiones
# [1] "baño"      "publicado"
#
# $Monserrat
# [1] "cocina" "frente"
#
# $`Monte Castro`
# [1] "aprox"     "publicado"
#
# $`Monte Chingolo`
# [1] "comercial"
#
# $`Monte Grande`
# [1] "publicado"
#
# $`Monte Hermoso`
# [1] "publicado"
#
# $Montoya
# [1] "dormitorios"
#
# $Moreno
# [1] "moreno"
#
# $Morón
# [1] "publicado"
#
# $Munro
# [1] "piso"
#
# $Muñiz
# [1] "publicado"
#
# $Necochea
# [1] "publicado"
#
# $Neuquén
# [1] "dormitorios"
#
# $Nogoyá
# [1] "inmobiliaria" "segura"
#
# $Nordelta
# [1] "nordelta"
#
# $`Nueva Atlantis`
# [1] "chalet"   "enero"    "parrilla" "quincena" "sistema"
#
# $Nuñez
# [1] "cocina"
#
# $Oberá
# [1] "publicado"
#
# $Olavarría
# [1] "inmobiliaria"
#
# $Oliveros
# [1] "santa"   "solares"
#
# $Olivos
# [1] "olivos"
#
# $`Olivos Golf Club`
# [1] "suite"
#
# $Once
# [1] "propiedades"
#
# $`Open Door`
# [1] "metros"
#
# $Ostende
# [1] "quincena"
#
# $`Pablo Podestá`
# [1] "barrio"    "publicado"
#
# $`Pacheco Golf Club`
# [1] "baño"
#
# $Palermo
# [1] "cocina"
#
# $`Palermo Chico`
# [1] "palermo"
#
# $`Palermo Hollywood`
# [1] "palermo"
#
# $`Palermo Soho`
# [1] "palermo"
#
# $`Palermo Viejo`
# [1] "palermo"
#
# $Paraná
# [1] "baño"
#
# $`Parque Avellaneda`
# [1] "baño"
#
# $`Parque Centenario`
# [1] "expensas"
#
# $`Parque Chacabuco`
# [1] "parque"
#
# $`Parque Chas`
# [1] "incas"  "parque" "subte"
#
# $`Parque Leloir`
# [1] "parque"
#
# $`Parque Luro`
# [1] "balcón"      "comedor"     "dormitorios" "living"
#
# $`Parque Patricios`
# [1] "parque"
#
# $`Paso de la Patria`
# [1] "cama"
#
# $`Paso del Rey`
# [1] "publicado"
#
# $Paternal
# [1] "baño"
#
# $Pehuajó
# [1] "publicado"
#
# $Pergamino
# [1] "publicado"
#
# $`Pichi Neuquen`
# [1] "house"
#
# $`Pico Truncado`
# [1] "comercial"         "electrodomesticos" "ideal"
# [4] "publicado"         "salon"             "supermercado"
#
# $Pilar
# [1] "pilar"
#
# $`Pilar del Lago`
# [1] "pilar"
#
# $`Pilar Green Park`
# [1] "pilar"      "superficie"
#
# $Pinamar
# [1] "quincena"
#
# $Piñeiro
# [1] "cuenta"
#
# $`Playa Grande`
# [1] "vista"
#
# $`Plaza Colón`
#  [1] "amplio"      "baño"        "cocina"      "colón"       "completo"
#  [6] "cubierto"    "espacio"     "guardacoche" "hermoso"     "luminoso"
# [11] "madera"      "pinotea"     "pisos"       "placard"     "plata"
# [16] "separada"    "zona"
#
# $`Plaza Mitre`
# [1] "oficina"
#
# $Plottier
# [1] "dormitorios"
#
# $Pontevedra
# [1] "metros"
#
# $Portezuelo
# [1] "casas"
#
# $Posadas
# [1] "baño"
#
# $`Potrero de Garay`
# [1] "metros"
#
# $`Potrero de los Funes`
# [1] "alquileralquiler" "inmobiliaria"     "muñoz"
#
# $`Presidente Perón`
# [1] "baño"
#
# $Progreso
# [1] "comercial"
#
# $`Pueblo Esther`
# [1] "baño"          "comercial"     "independencia" "parque"
# [5] "pueblo"
#
# $`Puerto Iguazú`
# [1] "inmobiliaria" "misiones"
#
# $`Puerto Madero`
# [1] "puerto"
#
# $`Puerto Madryn`
# [1] "propiedades"
#
# $Punilla
# [1] "publicado"
#
# $`Punta Alta`
# [1] "estufa"
#
# $`Punta Lara`
# [1] "dormitorios"
#
# $Quilmes
# [1] "quilmes"
#
# $`Rada Tilly`
# [1] "dormitorios"  "inmobiliaria"
#
# $`Rafael Calzada`
# [1] "publicado"
#
# $`Rafael Castillo`
# [1] "publicado"
#
# $Rafaela
# [1] "cocina"
#
# $`Ramos Mejía`
# [1] "ramos"
#
# $Ranelagh
# [1] "baño"        "persiana"    "propiedades"
#
# $Rawson
# [1] "centro"      "localidad"   "propiedad"   "propiedades" "tipo"
#
# $Recoleta
# [1] "cocina"
#
# $`Remedios de Escalada`
# [1] "publicado"
#
# $Resistencia
# [1] "baño"        "dormitorios"
#
# $Reta
# [1] "cama"     "semana"   "servicio"
#
# $Retiro
# [1] "comedor"
#
# $`Rincón de la Costa`
# [1] "barrio"
#
# $`Rincón de Milberg`
# [1] "tigre"
#
# $`Rincon Del Arca`
# [1] "barrio"
#
# $`Río Ceballos`
# [1] "comercial"
#
# $`Río Cuarto`
# [1] "publicado"
#
# $`Río Grande`
# [1] "grande"
#
# $`Río Negro`
#  [1] "baños"         "central"       "coche"         "departamentos"
#  [5] "dormitorios"   "edificio"      "habitaciones"  "lujo"
#  [9] "mercado"       "moderno"       "necesidad"     "negro"
# [13] "restaurantes"  "sonido"        "tiendas"       "tranquilo"
# [17] "trasera"
#
# $`Río Tercero`
# [1] "tercero"
#
# $`Rodeo del Medio`
# [1] "inmobiliaria" "medio"        "mendoza"
#
# $Roldán
# [1] "amplio"
#
# $Roosevelt
# [1] "apartamentos"
#
# $Rosario
# [1] "cocina"
#
# $`Rosario de Lerma`
#  [1] "acceso"       "amplios"      "baños"        "casona"       "cava"
#  [6] "colonial"     "comodo"       "corazon"      "cuenta"       "eduardo"
# [11] "estilo"       "galeria"      "habitaciones" "negocio"      "nuevo"
# [16] "once"         "propiedad"    "propiedades"  "rosario"      "salones"
# [21] "subsuelo"     "terraza"      "tres"
#
# $Saavedra
# [1] "cochera"  "cocina"   "comedor"  "saavedra"
#
# $`Sáenz Peña`
# [1] "baño"
#
# $Saldán
# [1] "amplio"   "inmueble"
#
# $Salta
# [1] "comercial"
#
# $`San Andres`
# [1] "comerciales"
#
# $`San Antonio de Areco`
# [1] "garantía"
#
# $`San Antonio De Padua`
# [1] "padua"
#
# $`San Bernardo`
# [1] "acapulco"
#
# $`San Carlos de Bariloche`
# [1] "baño"   "planta"
#
# $`San Clemente del Tuyú`
# [1] "calle"     "publicado"
#
# $`San Cristobal`
# [1] "piso"
#
# $`San Fernando`
# [1] "fernando"
#
# $`San Francisco`
# [1] "servicios"
#
# $`San Ignacio`
# [1] "jose"      "publicado"
#
# $`San Isidro`
# [1] "isidro"
#
# $`San Isidro Chico`
# [1] "baño"     "comedor"  "quincho"  "salida"   "servicio"
#
# $`San Javier`
# [1] "alquila"
#
# $`San Jose`
# [1] "sueldo"
#
# $`San José`
# [1] "baño"          "cocina"        "comercial"     "esquina"
# [5] "gonzalez"      "inmobiliarios" "negocios"      "propiedades"
# [9] "publicado"
#
# $`San Juan`
# [1] "cocina"
#
# $`San Justo`
# [1] "publicado"
#
# $`San Lorenzo`
# [1] "lorenzo" "santa"
#
# $`San Luis`
# [1] "dormitorio"
#
# $`San Martín`
# [1] "publicado"
#
# $`San Martín de los Andes`
# [1] "andes"     "argentina" "cmycpn"    "esquina"   "ideal"     "martin"
# [7] "patagonia" "ubicado"
#
# $`San Miguel`
# [1] "publicado"
#
# $`San Miguel de Tucumán`
# [1] "baño"
#
# $`San Miguel del Monte`
#  [1] "cerámica"    "comunicarse" "cuad"        "duplex"      "iguazu"
#  [6] "informes"    "lunes"       "oficina"     "publicado"   "sabados"
# [11] "tanque"      "unicamente"  "viernes"
#
# $`San Nicolás`
# [1] "cocina" "planta"
#
# $`San Patricio del Chañar`
# [1] "house"
#
# $`San Pedro`
# [1] "cocina"
#
# $`San Rafael`
# [1] "casas"
#
# $`San Roque`
# [1] "roque"
#
# $`San Salvador de Jujuy`
# [1] "comercial"
#
# $`San Telmo`
# [1] "baño"
#
# $`San Vicente`
# [1] "efectos"     "información"
#
# $`Santa-Catalina`
# [1] "baño"       "dormitorio" "laguna"
#
# $`Santa Barbara Barrio Cerrado`
# [1] "laguna" "santa"
#
# $`Santa Clara del Mar`
# [1] "chalet" "parque" "pileta" "santa"
#
# $`Santa Fe`
# [1] "cocina"
#
# $`Santa María`
# [1] "baño"     "barrio"   "estrenar" "privado"  "venta"    "vestidor"
#
# $`Santa Rosa`
# [1] "publicado"
#
# $`Santa Rosa de Calamuchita`
# [1] "santa"
#
# $`Santa Teresita`
# [1] "publicado"
#
# $`Santa Trinidad`
#  [1] "alquilercasa" "baño"         "cocina"       "comedor"      "diciembre"
#  [6] "disponible"   "dormitorio"   "ideal"        "lavadero"     "marcalain"
# [11] "patio"        "propiedades"  "renta"
#
# $`Santiago del Estero`
# [1] "habitación"
#
# $`Santiago Del Estero`
# [1] "publicado"
#
# $`Santo Tomé`
# [1] "inmobiliaria"
#
# $`Santos Lugares`
# [1] "cocina"
#
# $Sarandi
# [1] "metros"
#
# $Septiembre
# [1] "baño"       "comedor"    "septiembre"
#
# $`Sierra de los Padres`
# [1] "quincena"
#
# $`Solares del Talar`
# [1] "baño"
#
# $Sourigues
# [1] "cocina"      "propiedades"
#
# $`Tafí del Valle`
# [1] "publicado"
#
# $`Talar del Lago 1`
# [1] "baño"   "cuarto"
#
# $`Talar del lago 2`
# [1] "baño"
#
# $Tandil
# [1] "baño"        "dormitorios"
#
# $Tanti
# [1] "dormitorios"
#
# $Tapiales
# [1] "publicado"
#
# $Temperley
# [1] "baño"
#
# $`The Boating Club`
# [1] "amplio"   "cocina"   "parrilla" "piso"
#
# $Tigre
# [1] "comedor"
#
# $Toay
# [1] "publicado"
#
# $Tolosa
# [1] "comedor"     "dormitorios"
#
# $Torreón
# [1] "balcón"
#
# $`Tortugas Country Club`
# [1] "baño"       "izrastzoff"
#
# $Tortuguitas
# [1] "comedor"
#
# $Trelew
# [1] "alquileralquiler" "barra"            "cocina"           "desayunadora"
# [5] "livingcomedor"    "patagonia"
#
# $`Trenque Lauquen`
# [1] "inmobiliaria"
#
# $`Tres Arroyos`
# [1] "baño"   "dormit"
#
# $`Tres Cruces`
# [1] "apartamento" "frente"
#
# $`Tres de Febrero`
# [1] "inmomap" "traves"
#
# $Tribunales
# [1] "propiedades"
#
# $`Tristán Suárez`
# [1] "comercial"
#
# $`Troncos del Talar`
# [1] "baño"    "troncos"
#
# $Tucumán
# [1] "comercial"
#
# $Tunuyán
# [1] "calle"     "principal" "publicado" "ubicado"
#
# $Turdera
# [1] "publicado"
#
# $Unquillo
# [1] "baño"        "centro"      "ciudad"      "efectos"     "información"
# [6] "sierras"     "sueldo"
#
# $`Valentín Alsina`
# [1] "grupo" "inmob"
#
# $`Valeria del Mar`
# [1] "semana"
#
# $`Valle Hermoso`
# [1] "baño"    "privado"
#
# $`Veinticinco de Mayo`
# [1] "publicado"
#
# $`Velez Sarsfield`
# [1] "velez"
#
# $`Venado Tuerto`
# [1] "pixelinmobiliario" "publicado"
#
# $Versalles
# [1] "cocina"    "publicado"
#
# $`Vicente López`
# [1] "vicente"
#
# $Victoria
# [1] "comedor"
#
# $Viedma
# [1] "publicado"
#
# $`Villa Adelina`
# [1] "villa"
#
# $`Villa Allende`
# [1] "villa"
#
# $`Villa Ayacucho`
# [1] "estrenar" "parrilla"
#
# $`Villa Ballester`
# [1] "villa" "zona"
#
# $`Villa Bonich`
# [1] "propiedades"
#
# $`Villa Bosch`
# [1] "propiedades" "publicado"   "villa"
#
# $`Villa Carlos Paz`
# [1] "cocina"  "comedor"
#
# $`Villa Celina`
# [1] "barrio"     "cocina"     "dormitorio" "general"    "publicado"
#
# $`Villa Crespo`
# [1] "villa"
#
# $`Villa de Mayo`
# [1] "publicado"
#
# $`Villa del Parque`
# [1] "medidas"
#
# $`Villa Devoto`
# [1] "devoto"
#
# $`Villa Elisa`
# [1] "villa"
#
# $`Villa Elvira`
# [1] "dormitorios"
#
# $`Villa España`
# [1] "entradas"
#
# $`Villa General Belgrano`
# [1] "publicado"
#
# $`Villa General Mitre`
# [1] "publicado"
#
# $`Villa Gesell`
# [1] "quincena"
#
# $`Villa Giardino`
# [1] "dormitorios"
#
# $`Villa La Angostura`
# [1] "centro" "madera" "parque" "villa"
#
# $`Villa La Florida`
# [1] "amplio"      "campostrini" "mariano"
#
# $`Villa Libertad`
# [1] "propiedades"
#
# $`Villa Lugano`
# [1] "metros"
#
# $`Villa Luro`
# [1] "villa"
#
# $`Villa Luzuriaga`
# [1] "publicado"
#
# $`Villa Lynch`
# [1] "cocina"      "pisos"       "propiedades"
#
# $`Villa Madero`
# [1] "baño"        "ciudad"      "propiedades"
#
# $`Villa Maipu`
# [1] "planta"      "propiedades"
#
# $`Villa Martelli`
# [1] "propiedades"
#
# $`Villa Mercedes`
# [1] "asoc"      "bienes"    "inmuebles" "maria"
#
# $`Villa Nueva`
# [1] "comercial" "metros"
#
# $`Villa Ortuzar`
# [1] "cocina"
#
# $`Villa Paranacito`
# [1] "arroyo" "aviso"  "oferta"
#
# $`Villa Primera`
# [1] "parque"
#
# $`Villa Pueyrredón`
# [1] "villa"
#
# $`Villa Raffo`
# [1] "ceramicos" "piso"
#
# $`Villa Real`
# [1] "cocina"
#
# $`Villa Riachuelo`
# [1] "aire"
#
# $`Villa Rosa`
# [1] "comedor"
#
# $`Villa Santa Rita`
# [1] "balcón"  "placard" "santa"
#
# $`Villa Sarmiento`
# [1] "publicado"
#
# $`Villa Soldati`
# [1] "galpón"   "vivienda"
#
# $`Villa Tesei`
# [1] "publicado"
#
# $`Villa Udaondo`
# [1] "baño"
#
# $`Villa Urquiza`
# [1] "villa"
#
# $Villanueva
# [1] "baño"
#
# $`Virrey del Pino`
# [1] "publicado"
#
# $Virreyes
# [1] "avellaneda" "planta"
#
# $Vistalba
# [1] "cerro"
#
# $Wilde
# [1] "publicado"
#
# $`Yerba Buena`
# [1] "planta"
#
# $Zárate
# [1] "chacras"
#
# $Zelaya
# [1] "pilar"
